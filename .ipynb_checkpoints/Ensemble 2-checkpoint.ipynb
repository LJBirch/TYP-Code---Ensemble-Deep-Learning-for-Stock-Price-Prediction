# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, LSTM, GRU, RNN, SimpleRNNCell, Input, Flatten

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, recall_score, precision_score, f1_score

# %%
# Load in data from CSV.
df = pd.read_csv("./data/source_price_alt.csv");

# %%
# Convert index to date.
df.index = df.date;
df.drop('date', axis=1, inplace = True);

# %%
# Extract adjusted close column.
adjust_close = df.iloc[:,-1].values; 

# Normalize adjusted close data.
scaler = MinMaxScaler();
scaled_adjust_close = scaler.fit_transform(adjust_close.reshape(-1,1));

# Remove un-normalized column.
source_data = df.drop(['Adj Close'], axis=1)

# Set new column with normalized data.
source_data["scaled_adj_close"] = scaled_adjust_close

# %%
# Split into train test split.
train_validation_data, test_data = train_test_split(source_data, train_size=0.85, test_size=0.15, shuffle = False);

# %%
validation_data = train_validation_data[83:];
train_data = train_validation_data[:83];

# %%
# Split data into input X and output Y, by splitting into 'n' past days as input X and `m` coming days as Y.
def processData(data, look_back, forward_days,jump=1):
    A,B = [],[]
    for i in range(0,len(data) - look_back, jump):
        A.append(data[i:(i + look_back)])
        B.append(data[(i + look_back):(i + look_back + forward_days)])
    return np.array(A), np.array(B)

# %%
# Set model configurations.
look_back = 5
forward_days = 1
NUM_NEURONS = 50
EPOCHES = 100
BATCH_SIZE = 32
DROUP_OUT = 0.2

# %%
# Split into past and coming days.
m_training_data = train_data.to_numpy()
m_validation_data = validation_data.to_numpy()
m_test_data = test_data.to_numpy()

X_train, Y_train = processData(m_training_data, look_back, forward_days)
X_validation, Y_validation = processData(m_validation_data, look_back, forward_days)
X_test, Y_test = processData(m_test_data, look_back, forward_days)

Y_train = Y_train[:,0,-1]
Y_validation = Y_validation[:,0,-1]
Y_test = Y_test[:,0,-1]

# %%
# Setup LSTM Model
lstm_model = Sequential()

# First Layer
lstm_model.add(LSTM(units=NUM_NEURONS, return_sequences = True, input_shape=(X_train.shape[1],X_train.shape[2])))
lstm_model.add(Dropout(DROUP_OUT))

# Second Layer
lstm_model.add(LSTM(units=NUM_NEURONS, return_sequences = True))
lstm_model.add(Dropout(DROUP_OUT))

# Third Layer
lstm_model.add(LSTM(units=NUM_NEURONS, return_sequences = True))
lstm_model.add(Dropout(DROUP_OUT))

# Fourth Layer
lstm_model.add(LSTM(units=NUM_NEURONS))
lstm_model.add(Dropout(DROUP_OUT))

# Output Layer
lstm_model.add(Dense(forward_days))

# Train Model
lstm_model.compile(loss='mean_squared_error',optimizer='adam')
              
# Compile     
lstm_model.fit(X_train, Y_train, epochs = EPOCHES, batch_size = BATCH_SIZE)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 8s 8ms/step - loss: 0.2473
# Epoch 2/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2179
# Epoch 3/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1745
# Epoch 4/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1341
# Epoch 5/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0687
# Epoch 6/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0300

# %%
# Setup GRU Model
gru_model = Sequential()

# First Layer
gru_model.add(GRU(units = NUM_NEURONS, return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
gru_model.add(Dropout(DROUP_OUT))

# Second Layer
gru_model.add(GRU(units = NUM_NEURONS, return_sequences = True))
gru_model.add(Dropout(DROUP_OUT))

# Third Layer
gru_model.add(GRU(units = NUM_NEURONS, return_sequences = True))
gru_model.add(Dropout(DROUP_OUT))

# Fourth Layer
gru_model.add(GRU(units = NUM_NEURONS))
gru_model.add(Dropout(DROUP_OUT))

# Output Layer
gru_model.add(Dense(forward_days))

# Train Model
gru_model.compile(loss='mean_squared_error', optimizer='rmsprop')

gru_model.fit(X_train, Y_train, epochs = EPOCHES, batch_size = BATCH_SIZE)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 8s 9ms/step - loss: 0.2161
# Epoch 2/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0379
# Epoch 3/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0455
# Epoch 4/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0608
# Epoch 5/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0379
# Epoch 6/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0390
# Epoch 7/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0392
# Epoch 8/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0343
# Epoch 9/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0363
# Epoch 10/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0324
# Epoch 11/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0831
# Epoch 12/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0333
# Epoch 13/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0352
# Epoch 14/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0310
# Epoch 15/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0313
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0285
# Epoch 17/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0327
# Epoch 18/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0306
# Epoch 19/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0306
# Epoch 20/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0358
# Epoch 21/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0376
# Epoch 22/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0347
# Epoch 23/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0333
# Epoch 24/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0242
# Epoch 25/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0344
# Epoch 26/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0381
# Epoch 27/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0380
# Epoch 28/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0303
# Epoch 29/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0349
# Epoch 30/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0291
# Epoch 31/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0285
# Epoch 32/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0314
# Epoch 33/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0276
# Epoch 34/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0402
# Epoch 35/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0283
# Epoch 36/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0335
# Epoch 37/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0274
# Epoch 38/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0332
# Epoch 39/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0371
# Epoch 40/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0266
# Epoch 41/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0318
# Epoch 42/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0277
# Epoch 43/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0259
# Epoch 44/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0322
# Epoch 45/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0349
# Epoch 46/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0227
# Epoch 47/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0413
# Epoch 48/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0311
# Epoch 49/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0291
# Epoch 50/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0285
# Epoch 51/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0258
# Epoch 52/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0353
# Epoch 53/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0292
# Epoch 54/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0356
# Epoch 55/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0265
# Epoch 56/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0251
# Epoch 57/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0247
# Epoch 58/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0264
# Epoch 59/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0231
# Epoch 60/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0289
# Epoch 61/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0321
# Epoch 62/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0203
# Epoch 63/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0215
# Epoch 64/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0229
# Epoch 65/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0395
# Epoch 66/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0244
# Epoch 67/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0202
# Epoch 68/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0164
# Epoch 69/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0187
# Epoch 70/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0218
# Epoch 71/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0177
# Epoch 72/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0250
# Epoch 73/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0256
# Epoch 74/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0269
# Epoch 75/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0208
# Epoch 76/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0136
# Epoch 77/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0291
# Epoch 78/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 79/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0193
# Epoch 80/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 81/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0165
# Epoch 82/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0219
# Epoch 83/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0170
# Epoch 84/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0330
# Epoch 85/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0173
# Epoch 86/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0199
# Epoch 87/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0195
# Epoch 88/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0231
# Epoch 89/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 90/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0188
# Epoch 91/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0235
# Epoch 92/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0306
# Epoch 93/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0182
# Epoch 94/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0205
# Epoch 95/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0132
# Epoch 96/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0211
# Epoch 97/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0235
# Epoch 98/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0131
# Epoch 99/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0176
# Epoch 100/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0128

# %%
# Setup RNN Model
rnn_model = Sequential()

# First Layer
rnn_model.add(RNN(SimpleRNNCell(NUM_NEURONS), return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
rnn_model.add(Dropout(DROUP_OUT))

# Second Layer
rnn_model.add(RNN(SimpleRNNCell(NUM_NEURONS), return_sequences = True))
rnn_model.add(Dropout(DROUP_OUT))

# Third Layer
rnn_model.add(RNN(SimpleRNNCell(NUM_NEURONS), return_sequences = True))
rnn_model.add(Dropout(DROUP_OUT))

# Fourth Layer
rnn_model.add(RNN(SimpleRNNCell(NUM_NEURONS)))
rnn_model.add(Dropout(DROUP_OUT))

# Output Layer
rnn_model.add(Dense(forward_days))

# Train Model
rnn_model.compile(loss='mean_squared_error',optimizer='rmsprop')

rnn_model.fit(X_train, Y_train, epochs = EPOCHES, batch_size = BATCH_SIZE)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 3s 4ms/step - loss: 1.2592
# Epoch 2/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3200
# Epoch 3/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4483
# Epoch 4/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3663
# Epoch 5/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4264
# Epoch 6/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2450
# Epoch 7/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2088
# Epoch 8/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2321
# Epoch 9/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2907
# Epoch 10/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2547
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1905
# Epoch 12/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2067
# Epoch 13/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1645
# Epoch 14/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2556
# Epoch 15/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2008
# Epoch 16/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1385
# Epoch 17/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1849
# Epoch 18/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1499
# Epoch 19/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1457
# Epoch 20/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0979
# Epoch 21/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1031
# Epoch 22/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1837
# Epoch 23/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1053
# Epoch 24/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1431
# Epoch 25/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1671
# Epoch 26/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1191
# Epoch 27/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1026
# Epoch 28/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1253
# Epoch 29/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0873
# Epoch 30/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0973
# Epoch 31/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1376
# Epoch 32/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1170
# Epoch 33/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1014
# Epoch 34/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0788
# Epoch 35/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0936
# Epoch 36/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0712
# Epoch 37/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0793
# Epoch 38/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0819
# Epoch 39/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1016
# Epoch 40/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0845
# Epoch 41/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0890
# Epoch 42/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0933
# Epoch 43/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0762
# Epoch 44/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0607
# Epoch 45/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0653
# Epoch 46/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0637
# Epoch 47/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0479
# Epoch 48/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0578
# Epoch 49/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0535
# Epoch 50/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0946
# Epoch 51/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0657
# Epoch 52/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0619
# Epoch 53/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0741
# Epoch 54/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0581
# Epoch 55/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0491
# Epoch 56/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0504
# Epoch 57/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0393
# Epoch 58/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0449
# Epoch 59/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0557
# Epoch 60/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0626
# Epoch 61/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0590
# Epoch 62/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0701
# Epoch 63/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0349
# Epoch 64/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0445
# Epoch 65/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0395
# Epoch 66/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0522
# Epoch 67/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0605
# Epoch 68/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0407
# Epoch 69/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0562
# Epoch 70/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0465
# Epoch 71/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 72/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0310
# Epoch 73/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0368
# Epoch 74/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0320
# Epoch 75/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 76/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0396
# Epoch 77/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0270
# Epoch 78/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0329
# Epoch 79/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0363
# Epoch 80/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0530
# Epoch 81/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0344
# Epoch 82/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0341
# Epoch 83/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0626
# Epoch 84/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0352
# Epoch 85/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0519
# Epoch 86/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0332
# Epoch 87/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 88/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0274
# Epoch 89/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0342
# Epoch 90/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 91/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 92/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0403
# Epoch 93/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0310
# Epoch 94/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 95/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 96/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 97/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0371
# Epoch 98/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0263
# Epoch 99/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0265
# Epoch 100/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0288

# %%
# Carry Out Validation Predictions
Xm1 = lstm_model.predict(X_validation)
Xm2 = gru_model.predict(X_validation)
Xm3 = rnn_model.predict(X_validation)
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000022E1710CE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000022E19822AF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000022E1C8891F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
Y_validation = Y_validation.reshape(-1,1)
m2_Y_validation = scaler.inverse_transform(Y_validation)
Y_validation.reshape(-1,1)

m1_prediction = scaler.inverse_transform(Xm1)
m2_prediction = scaler.inverse_transform(Xm2)
m3_prediction = scaler.inverse_transform(Xm3)

# %%
# Carry out sub-model predictions.
Xmt1 = lstm_model.predict(X_test)

Xmt2 = gru_model.predict(X_test)

Xmt3 = rnn_model.predict(X_test)

Y_test.reshape(-1, 1)

m1_x_test = scaler.inverse_transform(Xmt1)
m2_x_test = scaler.inverse_transform(Xmt2)
m3_x_test = scaler.inverse_transform(Xmt3)

Y_test = Y_test.reshape(-1,1)
m2_Y_test = scaler.inverse_transform(Y_test)

# %%
lstm_model_mse = mean_squared_error(m1_x_test, m2_Y_test)
print("LSTM MSE: ", lstm_model_mse)
# Out:
# LSTM MSE:  386.61340823962064

# %%
gru_model_mse = mean_squared_error(m2_x_test, m2_Y_test)
print("GRU MSE: ", gru_model_mse)
# Out:
# GRU MSE:  212.65773533133014

# %%
rnn_model_mse = mean_squared_error(m3_x_test, m2_Y_test)
print("RNN MSE: ", rnn_model_mse)
# Out:
# RNN MSE:  286.75748667593547

# %%
# Generate generic sequential model.
dff_output_model = Sequential()

# Desired activation function.
activ_func = "relu"

# Set input layer and size.
dff_output_model.add(Flatten(input_shape=(3,)))

# Hidden Layer 1
dff_output_model.add(Dense(18, activation = activ_func))

# Hidden Layer 2
dff_output_model.add(Dense(9, activation = activ_func))

# Hidden Layer 3
dff_output_model.add(Dense(2, activation = activ_func))

# Output Layer
dff_output_model.add(Dense(1))

# %%
# Normalize X validation data.
scaler = MinMaxScaler()
normalized_x_validation1 = scaler.fit_transform(m1_prediction)
normalized_x_validation2 = scaler.fit_transform(m2_prediction)
normalized_x_validation3 = scaler.fit_transform(m3_prediction)

# Normalize Y validation data.
normalized_y_validation = scaler.fit_transform(m2_Y_validation)

# Concate training data.
level1_train_data = np.concatenate((normalized_x_validation1, normalized_x_validation2, normalized_x_validation3), axis=-1)

# %%
# Compile model.
dff_output_model.compile(optimizer='rmsprop',loss='mean_squared_error', metrics=['mae'])

# Fit model to training data.
dff_output_model.fit(level1_train_data, normalized_y_validation, epochs = 100, batch_size = 2)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 831us/step - loss: 0.4566 - mae: 0.5894
# Epoch 2/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.2526 - mae: 0.4365
# Epoch 3/100
# 7/7 [==============================] - 0s 824us/step - loss: 0.1883 - mae: 0.3496
# Epoch 4/100
# 7/7 [==============================] - 0s 831us/step - loss: 0.1714 - mae: 0.3244
# Epoch 5/100
# 7/7 [==============================] - 0s 831us/step - loss: 0.1291 - mae: 0.2780
# Epoch 6/100
# 7/7 [==============================] - 0s 782us/step - loss: 0.1563 - mae: 0.3275
# Epoch 7/100
# 7/7 [==============================] - 0s 906us/step - loss: 0.1079 - mae: 0.2480
# Epoch 8/100
# 7/7 [==============================] - 0s 969us/step - loss: 0.1315 - mae: 0.3142
# Epoch 9/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1228 - mae: 0.2837
# Epoch 10/100
# 7/7 [==============================] - 0s 990us/step - loss: 0.0932 - mae: 0.2444
# Epoch 11/100
# 7/7 [==============================] - 0s 831us/step - loss: 0.0815 - mae: 0.2262
# Epoch 12/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.0677 - mae: 0.2206
# Epoch 13/100
# 7/7 [==============================] - 0s 998us/step - loss: 0.0755 - mae: 0.2417
# Epoch 14/100
# 7/7 [==============================] - 0s 1000us/step - loss: 0.1007 - mae: 0.2764
# Epoch 15/100
# 7/7 [==============================] - 0s 975us/step - loss: 0.0713 - mae: 0.2344
# Epoch 16/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.0831 - mae: 0.2523
# Epoch 17/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.0784 - mae: 0.2337
# Epoch 18/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.0687 - mae: 0.2118
# Epoch 19/100
# 7/7 [==============================] - 0s 955us/step - loss: 0.0811 - mae: 0.2490
# Epoch 20/100
# 7/7 [==============================] - 0s 991us/step - loss: 0.0608 - mae: 0.2171
# Epoch 21/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0854 - mae: 0.2558
# Epoch 22/100
# 7/7 [==============================] - 0s 969us/step - loss: 0.0771 - mae: 0.2379
# Epoch 23/100
# 7/7 [==============================] - 0s 995us/step - loss: 0.0831 - mae: 0.2608
# Epoch 24/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.0804 - mae: 0.2466
# Epoch 25/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.1263 - mae: 0.3230
# Epoch 26/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.
# 7/7 [==============================] - 0s 832us/step - loss: 0.0526 - mae: 0.1871
# Epoch 93/100
# 7/7 [==============================] - 0s 829us/step - loss: 0.0642 - mae: 0.2251
# Epoch 94/100
# 7/7 [==============================] - 0s 831us/step - loss: 0.0625 - mae: 0.2093
# Epoch 95/100
# 7/7 [==============================] - 0s 909us/step - loss: 0.0366 - mae: 0.1535
# Epoch 96/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.0470 - mae: 0.1891
# Epoch 97/100
# 7/7 [==============================] - 0s 831us/step - loss: 0.0419 - mae: 0.1806
# Epoch 98/100
# 7/7 [==============================] - 0s 831us/step - loss: 0.0458 - mae: 0.1744
# Epoch 99/100
# 7/7 [==============================] - 0s 830us/step - loss: 0.0332 - mae: 0.1379
# Epoch 100/100
# 7/7 [==============================] - 0s 831us/step - loss: 0.0594 - mae: 0.2044

# %%
# Normalize test data.
normalized_x_test1 = scaler.fit_transform(m1_x_test)
normalized_x_test2 = scaler.fit_transform(m2_x_test)
normalized_x_test3 = scaler.fit_transform(m3_x_test)

# Concatanate the test data.
level1_test_data = np.concatenate((normalized_x_test1, normalized_x_test2, normalized_x_test3), axis=-1)

# %%
Xt3 = dff_output_model.predict(level1_test_data)

predicted_stock_price = scaler.inverse_transform(Xt3)
# Out:
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000022E1D029790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
mse = mean_squared_error(predicted_stock_price, m2_Y_test)
print("Blending Ensemble MSE: ", mse)
# Out:
# Blending Ensemble MSE:  193.0740437015592

# %%
def convert_to_classifier(values, debug=False):
    binary_results = np.zeros(len(values) - 1)
    for idx, val in enumerate(values):
        if idx < 1:
            continue
        if values[idx] > values[idx - 1]:
            binary_results[idx - 1] = 1
            if debug:
                print(f'Increase: {values[idx]} vs {values[idx - 1]}')
        else:
            if debug:
                print(f'Decrease: {values[idx]} vs {values[idx - 1]}')
            
    return binary_results

# %%
def calc_mda(true_direction, predicted_direction, debug=False):
    correct_predictions = 0
    for idx, val in enumerate(true_direction):
        if debug:
            print(f'Predicted: {prediction_binary[idx]} vs actual {true_direction[idx]}')
        if predicted_direction[idx] == true_direction[idx]:
            correct_predictions = correct_predictions + 1
    
    if debug:
        print(f'Correct Predictions: {correct_predictions} out of {len(predicted_direction)}.')
    
    mda = correct_predictions / len(predicted_direction)
    return mda

# %%
# Output results.
prediction_binary = convert_to_classifier(predicted_stock_price, debug=False)
test_binary = convert_to_classifier(m2_Y_test, debug=False)
recall = recall_score(test_binary, prediction_binary)
precision = precision_score(test_binary, prediction_binary)
f1_score = f1_score(test_binary, prediction_binary)
mda = calc_mda(test_binary, prediction_binary, debug=False)
print(f'Recall: {recall}\nPrecision: {precision}\nF1 Score: {f1_score}\nMDA: {mda * 100}%\nBlending Ensemble MSE: {mse}')
# Out:
# Recall: 0.4
# Precision: 0.4
# F1 Score: 0.4000000000000001
# MDA: 53.84615384615385%
# Blending Ensemble MSE: 193.0740437015592
